# %% [markdown]
# <h1 style='text-align: center; font-weight: 900; color: #114232; background-color: #ffffff'>2024. 03. 08. 시험</h1>

# %% [markdown]
# <h6 style='float: right;'>성명 : 김나경</h6>

# %% [markdown]
# <h5 style='background-color: #114232; color: #ffffff; text-align: center; padding: 16px;'>데이터 분석 기초 기술 활용</h5>

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>1. 라인 플롯, 바 플롯, 스케터 플롯, 파이 플롯에 대해서 간단히 설명하고 어떤 경우에 사용되는지 설명하시오.</h6>

# %% [markdown]
# **1번 답안**
#
# 라인 플롯 : matplotlib에서 가장 기본적인 그래프로 선 그래프이다. 시간이나 다른 연속적인 변수에 따른 데이터의 변화를 시각적으로 표현하는데 사용된다. 주로 시계열 데이터나 연속적인 데이터의 추이를 보여줄 때 유용하다. pyplot 패키지의 `plot()` 메서드로 첫 번째 인자는 x축, 두 번째 인자는 y축에 대응하는 매개변수를 넣어 생성한다. 이때 매개변수로 리스트 혹은 배열을 전달한다.
#
# 바 플롯 : 막대 그래프로 범주형 데이터를 시각화하는데 사용된다. 주로 카테고리나 그룹 간의 비교를 할 때 유용하다. `bar()`, `barh()` 메서드로 첫 번째 인자는 x축(카테고리), 두 번째 인자는 y축(값)) 대응하는 매개변수를 넣어 생성한다.
#
# 스케터 플롯 : 산점도 그래프로 두 변수 간의 관계를 시각화하는데 사용된다. 주로 연속형 데이터를 시각화할 때 유용하다. `scatter()` 메서드로 첫 번째 인자는 x축, 두 번째 인자는 y축에 대응하는 매개변수를 넣어 생성하고 점의 위치는 (x, y)라는 좌표 값으로 표현할 수 있다.
#
# 파이 플롯 : 원 그래프로 전체 데이터에서 각 부분이 차지하는 비율을 시각적으로 표현하는데 사용된다. 주로 범주형 데이터의 구성을 보여줄 때 유용하다. `pie()` 메서드로 첫 번째 인자는 각 부분의 크기를 나타내는 데이터(sizes)를 전달하고 `labels=`를 통해서 라벨을 지정하며 `autopct=`를 통해 각 부분 크기의 %를 표시한다. 이때 차트가 원 형태를 유지하기 위해서는 `axis('equal')`을 지정해야 한다.

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>2. numpy 배열에서 벡터화 연산이 파이썬 기본 리스트를 사용한 연산보다 어떤점에서 장점인지 설명하시오.</h6>

# %% [markdown]
# **2번 답안**
#
# 1. numpy 배열 연산은 C로 구현된 내부 반복문을 사용하기 때문에 파이썬 기본 리스트를 사용한 연산보다 빠르다는 장점이 있다.
#
# 2. 벡터화 연산을 이용한 것이기 때문에 간단한 코드로도 복잡한 선형 대수 연산을 수행할 수 있다는 장점이 있다. 또한 배열 인덱싱을 사용한 Query 기능을 통해서도 복잡한 수식에 대한 연산의 간결성을 확인할 수 있다.
#
# 3. numpy 배열은 연속된 메모리 블록에 저장되므로 파이썬의 리스트보다 메모리에 데이터를 효율적으로 저장할 수 있다는 장점이 있다. 또한 numpy 배열은 데이터 유형을 명시적으로 지정할 수 있기에 메모리 사용을 최적화할 수 있다.
#
# 4. numpy에서는 브로드캐스팅(Broadcasting)이라는 기능을 제공하는데 이는 서로 다른 크기의 배열 간에도 산술 연산을 수행할 수 있다는 장점이 있다. 브로드캐스팅은 코드의 가독성과 유연성을 높인다는 측면에서 파이썬 리스트 연산보다 효율적이라고 할 수 있다.

# %% [markdown]
# <br />

# %% [markdown]
# <h5 style='background-color: #114232; color: #ffffff; text-align: center; padding: 16px;'>분석 데이터 전처리</h5>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# %%
fm._get_fontconfig_fonts()
font_location = './font/NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
mpl.rc('font', family=font_name)

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>3. 함께 첨부된 officetel_estate.csv 파일을 DataFrame 형식의  officetel_estate 라는 변수로 불러오시오.</h6>

# %%
# 3번 답안
officetel_estate = pd.read_csv('officetel_estate.csv')
officetel_estate
# Out:
#      sequence          locale year_month  \
# 0           1      nationwide    2020-07
# 1           2    metropolitan    2020-07
# 2           3        province    2020-07
# 3           4           seoul    2020-07
# 4           5  seoul-downtown    2020-07
# ..        ...             ...        ...
# 726       727         gwangju    2024-01
# 727       728         daejeon    2024-01
# 728       729           ulsan    2024-01
# 729       730          sejong    2024-01
# 730       731        gyeonggi    2024-01
#
#      between_lease_and_lease_deposit_ratio  lease_to_sale_ratio  \
# 0                                     7.95                83.54
# 1                                     7.46                84.31
# 2                                     9.96                80.33
# 3                                     7.10                82.80
# 4                                     6.13                79.55
# ..                                     ...                  ...
# ...

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>4. officetel_estate DataFrame 객체의 sequence 열을 행 인덱스로 변경하여 officetel_estate 변수에 저장하시오.</h6>

# %%
# 4번 답안
officetel_estate = officetel_estate.set_index('sequence')
officetel_estate
# Out:
#                   locale year_month  between_lease_and_lease_deposit_ratio  \
# sequence
# 1             nationwide    2020-07                                   7.95
# 2           metropolitan    2020-07                                   7.46
# 3               province    2020-07                                   9.96
# 4                  seoul    2020-07                                   7.10
# 5         seoul-downtown    2020-07                                   6.13
# ...                  ...        ...                                    ...
# 727              gwangju    2024-01                                   7.86
# 728              daejeon    2024-01                                  11.42
# 729                ulsan    2024-01                                   7.62
# 730               sejong    2024-01                                   6.05
# 731             gyeonggi    2024-01                                   7.09
#
# ...

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>5. officetel_estate DataFrame 객체에서 지역이 nationwide인 행만 출력하시오.</h6>

# %%
# 5번 답안
officetel_estate[officetel_estate.locale.str.contains('nationwide')]
# Out:
#               locale year_month  between_lease_and_lease_deposit_ratio  \
# sequence
# 1         nationwide    2020-07                                   7.95
# 18        nationwide    2020-08                                   7.93
# 35        nationwide    2020-09                                   7.92
# 52        nationwide    2020-10                                   7.91
# 69        nationwide    2020-11                                   7.90
# 86        nationwide    2020-12                                   7.89
# 103       nationwide    2021-01                                   7.86
# 120       nationwide    2021-02                                   7.89
# 137       nationwide    2021-03                                   7.92
# 154       nationwide    2021-04                                   7.86
# 171       nationwide    2021-05                                   7.83
# 188       nationwide    2021-06                                   7.80
# ...

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>6. officetel_estate DataFrame 객체에서 locale을 기준으로 그룹화하여 각 locale의 평당 매매가 (average_price_per_unit)의 평균을 DataFrame으로 출력하시오. (평균은 소수점 이하 3번째 자리에서 반올림하시오.)</h6>

# %%
# 6번 답안
officetel_estate.groupby(officetel_estate.locale)[['average_price_per_unit']].mean().round(2)
# Out:
#                     average_price_per_unit
# locale
# busan                              3473.35
# daegu                              3464.33
# daejeon                            2295.88
# gwangju                            2343.26
# gyeonggi                           4967.44
# incheon                            3186.12
# metropolitan                       5880.21
# nationwide                         5371.81
# province                           3273.63
# sejong                             3618.72
# seoul                              7469.77
# seoul-downtown                     8347.40
# seoul-northeastern                 5827.02
# seoul-northwestern                 7610.23
# seoul-southeastern                 8634.44
# seoul-southwestern                 6964.14
# ulsan                              3179.77

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>7. officetel_estate DataFrame 객체에서 행 인덱스로 year_month, 열 인덱스로 locale, 데이터로 average_price_per_unit을 가지는 피봇 테이블을 출력하시오.</h6>

# %%
# 7번 답안
officetel_estate.pivot(index='year_month', columns='locale', values='average_price_per_unit')
# Out:
# locale      busan  daegu  daejeon  gwangju  gyeonggi  incheon  metropolitan  \
# year_month
# 2020-07      3494   3537     2253     2337      4809     3112          5751
# 2020-08      3491   3535     2251     2336      4813     3110          5755
# 2020-09      3485   3532     2250     2334      4815     3106          5755
# 2020-10      3485   3534     2249     2335      4822     3107          5760
# 2020-11      3482   3524     2255     2336      4824     3102          5758
# 2020-12      3483   3528     2258     2335      4833     3097          5762
# 2021-01      3481   3523     2260     2340      4842     3097          5767
# 2021-02      3486   3525     2263     2340      4855     3094          5775
# 2021-03      3483   3527     2266     2341      4876     3099          5786
# 2021-04      3484   3529     2271     2342      4883     3107          5792
# 2021-05      3487   3532     2276     2345      4897     3122          5798
# ...

# %% [markdown]
# <br />

# %% [markdown]
# <h5 style='background-color: #114232; color: #ffffff; text-align: center; padding: 16px;'>빅데이터 분석 결과 시각화</h5>

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>8. officetel_estate DataFrame 객체에서 nationwide의 year_month (2021년)에 대한 average_price_per_unit 변화를 나타내는 선 그래프를 pandas의 plot을 활용하여 아래와 같이 출력하시오.</h6>

# %% [markdown]
# <img src='./mock_image/6.png' />

# %%
# 8번 답안
officetel_estate[officetel_estate.year_month.str.contains('2021')].pivot(index='year_month', columns='locale', values='average_price_per_unit').nationwide.plot()
plt.title('2021년 전국 평균 평당 매매가')
plt.xlabel('연 - 월')
plt.ylabel('평당 평균 매매가')
plt.grid(True)
plt.show()

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>9. officetel_estate DataFrame 객체에서 seoul-northeastern, seoul-northwestern, seoul-southwestern, seoul-southeastern의 year_month (2021년)에 대한 average_price_per_unit 변화를 나타내는 막대 그래프를 pandas의 plot을 활용하여 아래와 같이 출력하시오. (figure의 사이즈는 12, 8)</h6>

# %% [markdown]
# <img src='./mock_image/7.png' />

# %%
# 9번 답안
officetel_estate[officetel_estate.year_month.str.contains('2021')].pivot(index='year_month', 
    columns='locale', values='average_price_per_unit')[['seoul-northeastern', 
        'seoul-northwestern', 'seoul-southwestern', 'seoul-southeastern']].plot.bar(rot=0, 
                                                                                    figsize=(12, 8))
plt.ylim(5000, 10000)
plt.title('2021년 서울 지역의 평균 평당 매매가')
plt.xlabel('연 -월')
plt.ylabel('평균 평당 매매가')
plt.grid(True)
plt.show()

# %% [markdown]
# <br />

# %% [markdown]
# <h6 style='font-weight: 700; color: #214151; background-color: #ffffff'>10. officetel_estate DataFrame 객체에서 locale을 기준으로 그룹화하여 각 locale의 평당 전세가 대비 보증금 평균 (average_lease_on_deposit_price_per_unit)의 최고 값 중 서울의 막대그래프를  pandas의 plot을 활용하여 아래와 같이 출력하시오. (figure의 사이즈는 12, 8, 평균은 소수점 이하 3번째 자리에서 반올림하시오.)</h6>

# %% [markdown]
# <img src='./mock_image/8.png' />

# %%
# 10번 답안
officetel_estate[officetel_estate.locale.str.contains('seoul')].groupby(officetel_estate.locale).average_lease_on_deposit_price_per_unit.max().plot.bar(rot=0, figsize=(12, 8))
plt.ylim(6000, 8000)
plt.title('서울 지역의 평당 전세가 대비 보증금 평균의 최고값')
plt.xlabel('지역')
plt.ylabel('평당 전세가 대비 보증금 평균')
plt.grid(True)
plt.show()
